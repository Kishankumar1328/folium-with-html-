# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishankumar1328/folium-with-html-/blob/main/Famous_hill_stations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium

# %%
map=folium.Map(location=(11.1271,78.387451),zoom_start=8)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fac419fa77077b2480a8cc31c4f1a51 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fac419fa77077b2480a8cc31c4f1a51&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5fac419fa77077b2480a8cc31c4f1a51 = L.map(
#                 &quot;map_5fac419fa77077b2480a8cc31c4f1a51&quot;,
#                 {
#                     center: [11.1271, 78.387451],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_87dc93742177ed35ea6fbeb859750eaf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5fac419fa77077b2480a8cc31c4f1a51);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
yercaud_marker = folium.Marker(
    location=[11.77, 78.21],
    tooltip="Yercaud",
    icon=folium.Icon(icon='cloud',icon_color="white",color="darkblue"),
    popup=folium.Html(
        "<h1>King Of Eastern Ghats</h1>"
        "<img src='/content/yercaud1.jpg'>"
        "<p>Nestled 'midst emerald hills, Yercaud's allure unfolds,<br>"
        "Whispers of serenity in mist-kissed tales, a tranquil haven to behold</p>",
        script=True
    )
).add_to(map)
folium.Circle(location=(11.77, 78.21),
              radius=5000,popup="Hill Station",
              color="blue",
              fill=True,
              fill_color="blue").add_to(map)

# %%
kodikanal_marker = folium.Marker(
    location=[10.23, 77.49],
    tooltip="Kodikana",
    icon=folium.Icon(icon='cloud',icon_color="white",color="darkblue"),
    popup=folium.Html(
        "<h1>the princes of Hill Station</h1>"
        "<img src='/content/kodaikanal.jpg'>"
        "<p>Nestled 'Amidst the mist-kissed embrace of Kodai's hills,<br>"
        "Nature's canvas unfolds, a tranquil haven that serenity instills.</p>",
        script=True
    )
).add_to(map)

folium.Circle(location=(10.23, 77.49),
              radius=5000,popup="Hill Station",
              color="blue",
              fill=True,
              fill_color="blue").add_to(map)

# %%
ooty_marker = folium.Marker(
    location=[11.410000,76.699997],
    tooltip="Ooty",
    icon=folium.Icon(icon='cloud',icon_color="white",color="darkblue"),
    popup=folium.Html(
        "<h1>Queen of the Hills</h1>"
        "<img src='/content/ooty.jpg'>"
        "<p>In Ooty's emerald embrace, the Nilgiri's whispers unfold,<br>"
        "A symphony of mist and tea, where tales of serenity are told.</p>",
        script=True
    )
).add_to(map)
folium.Circle(location=(11.410000,76.699997),
              radius=5000,popup="Hill Station",
              color="blue",
              fill=True,
              fill_color="blue").add_to(map)

# %%
yelagiri_marker = folium.Marker(
    location=[12.59,78.63],
    tooltip="Yelagiri",
    icon=folium.Icon(icon='cloud',icon_color="white",color="darkblue"),
    popup=folium.Html(
        "<h1>Poor Man's Ooty</h1>"
        "<img src='/content/yelagiri.jpg'>"
        "<p>Yelagiri's verdant hills weave tales of tranquility,<br>"
        "Nature's poetry unfolds, a serene retreat of simplicity.</p>",
        script=True
    )
).add_to(map)
folium.Circle(location=(12.59,78.63),
              radius=5000,popup="Hill Station",
              color="blue",
              fill=True,
              fill_color="blue").add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fac419fa77077b2480a8cc31c4f1a51 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fac419fa77077b2480a8cc31c4f1a51&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5fac419fa77077b2480a8cc31c4f1a51 = L.map(
#                 &quot;map_5fac419fa77077b2480a8cc31c4f1a51&quot;,
#                 {
#                     center: [11.1271, 78.387451],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_87dc93742177ed35ea6fbeb859750eaf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5fac419fa77077b2480a8cc31c4f1a51);
#
#
#             var marker_78171202c8b7e62025499b4e24668271 = L.marker(
#                 [11.77, 78.21],
#                 {}
#             ).addTo(map_5fac419fa77077b2480a8cc31c4f1a51);
#
#
#             var icon_6432c07870fa6a1f649ebdca977dc405 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_78171202c8b7e62025499b4e24668271.setIcon(icon_6432c07870fa6a1f649ebdca977dc405);
#
#
#         var popup_78d55cb646427473a992c25d3321c304 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_77652d75fd81d82676da142e8441b7c1 = $(`&lt;div id=&quot;html_77652d75fd81d82676da142e8441b7c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;branca.element.Html object at 0x7c699c89ad40&gt;&lt;/div&gt;`)[0];
#                 popup_78d55cb646427473a992c25d3321c304.setContent(html_77652d75fd81d82676da142e8441b7c1);
#
#
#
#         marker_78171202c8b7e62025499b4e24668271.bindPopup(popup_78d55cb646427473a992c25d3321c304)
#         ;
#
#
#
#
#             marker_78171202c8b7e62025499b4e24668271.bindTooltip(
#                 `&lt;div&gt;
#                      Ooty
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3289187dd11d06974b098cf89719adfc = L.marker(
#                 [10.23, 77.49],
#                 {}
#             ).addTo(map_5fac419fa77077b2480a8cc31c4f1a51);
#
#
#             var icon_af7f2a7d63a50fc8bc64ff8853b8e4e4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3289187dd11d06974b098cf89719adfc.setIcon(icon_af7f2a7d63a50fc8bc64ff8853b8e4e4);
#
#
#         var popup_5f59bd9b0eff6c5150f8a65462a720cf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8182b61a0e34952754bb15eb1c37e023 = $(`&lt;div id=&quot;html_8182b61a0e34952754bb15eb1c37e023&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;branca.element.Html object at 0x7c699c898340&gt;&lt;/div&gt;`)[0];
#                 popup_5f59bd9b0eff6c5150f8a65462a720cf.setContent(html_8182b61a0e34952754bb15eb1c37e023);
#
#
#
#         marker_3289187dd11d06974b098cf89719adfc.bindPopup(popup_5f59bd9b0eff6c5150f8a65462a720cf)
#         ;
#
#
#
#
#             marker_3289187dd11d06974b098cf89719adfc.bindTooltip(
#                 `&lt;div&gt;
#                      Kodikana
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6d6a15d715fc7a99def7188c5753cb22 = L.marker(
#                 [11.77, 78.21],
#                 {}
#             ).addTo(map_5fac419fa77077b2480a8cc31c4f1a51);
#
#
#             var icon_06c09300bfd939448906b02a930f5b18 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6d6a15d715fc7a99def7188c5753cb22.setIcon(icon_06c09300bfd939448906b02a930f5b18);
#
#
#         var popup_4b0572fcb3b56575d53de4c13aae337f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a86032f747c59fbc5e9d58cea8db5e1a = $(`&lt;div id=&quot;html_a86032f747c59fbc5e9d58cea8db5e1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;branca.element.Html object at 0x7c699c8621a0&gt;&lt;/div&gt;`)[0];
#                 popup_4b0572fcb3b56575d53de4c13aae337f.setContent(html_a86032f747c59fbc5e9d58cea8db5

# %%
map.save("famous_hill_station_in_tamilnadu.html")
